# %%
import numpy as np

def convert_to_matrix(file):
    '''Convert the input file to a matrix of integers.'''
    rows = file.splitlines()
    height = len(rows)
    width = len(rows[0])
    print(f"Height: {height} - Width: {width}")
    matrix = np.zeros((height, width), dtype=int)    
    for i, row in enumerate(rows):
        for j, char in enumerate(row):
            matrix[i, j] = int(char)
    print(f"Matrix:\n{matrix}")
    print(f"Matrix shape: {matrix.shape}")
    return matrix

def num_edge_elements(matrix):
    '''Count the number of edge elements in a matrix.'''
    n = matrix.shape[0]
    m = matrix.shape[1]
    return 2*n + 2*m - 4

def check_tree(matrix, i, j):
    n = matrix.shape[0]
    m = matrix.shape[1]
    tree = matrix[i, j]
    
    top_vis = True
    bottom_vis = True
    left_vis = True
    right_vis = True
    
    for k in range(0, i):
        if matrix[k, j] >= tree:
            top_vis = False
            break
    
    for k in range(i+1, n):
        if matrix[k, j] >= tree:
            bottom_vis = False
            break
        
    for k in range(0, j):
        if matrix[i, k] >= tree:
            left_vis = False
            break
        
    for k in range(j+1, m):
        if matrix[i, k] >= tree:
            right_vis = False
            break
    
    is_visible = top_vis or bottom_vis or left_vis or right_vis
    
    if is_visible:
        print(f"Tree value {matrix[i,j]} at ({i}, {j}) is visible.")
    
    return is_visible
        

def calc_visible_trees(matrix):
    '''Calculate the number of visible trees in a matrix.'''
    n = matrix.shape[0]
    m = matrix.shape[1]
    num_trees = 0
    for i in range(1, n-1):
        for j in range(1, m-1):
            if check_tree(matrix, i, j):
                num_trees += 1
    return num_trees

def part1():
    file = open("input.txt", "r").read()
    matrix = convert_to_matrix(file)
    return num_edge_elements(matrix) + calc_visible_trees(matrix)

### Part 2

def scenic(matrix, i, j):
    n = matrix.shape[0]
    m = matrix.shape[1]
    tree = matrix[i, j]
    print(f"Tree value {tree} at ({i}, {j})")
    
    # trees seen to the top
    top_trees = 0
    for k in range(i - 1, -1, -1):
        print(f"checking {matrix[k, j]}")
        if matrix[k, j] < tree:
            top_trees += 1
        elif matrix[k, j] >= tree:
            top_trees += 1
            break
    
    # trees seen to the bottom
    bottom_trees = 0
    for k in range(i + 1, n):
        if matrix[k, j] < tree:
            bottom_trees += 1
        elif matrix[k, j] >= tree:
            bottom_trees += 1
            break
        
    # trees seen to the left
    left_trees = 0
    for k in range(j - 1, -1, -1):
        if matrix[i, k] < tree:
            left_trees += 1
        elif matrix[i, k] >= tree:
            left_trees += 1
            break
    
    # trees seen to the right
    right_trees = 0
    for k in range(j + 1, m):
        if matrix[i, k] < tree:
            right_trees += 1
        elif matrix[i, k] >= tree:
            right_trees += 1
            break
        
    return top_trees * bottom_trees * left_trees * right_trees

    

def part2():
    file = open("input.txt", "r").read()
    matrix = convert_to_matrix(file)
    
    max_scenic = 0
    for i in range(1, matrix.shape[0] - 1):
        for j in range(1, matrix.shape[1] - 1):
            num = scenic(matrix, i, j)
            if num > max_scenic:
                max_scenic = num
    
    return max_scenic

part2()
# Out:
# Height: 99 - Width: 99
# Matrix:
# [[0 0 0 ... 2 1 2]
#  [0 2 0 ... 2 1 0]
#  [0 1 2 ... 1 2 2]
#  ...
#  [2 2 1 ... 1 2 1]
#  [2 1 1 ... 0 2 2]
#  [2 0 2 ... 2 2 1]]
# Matrix shape: (99, 99)
# Tree value 2 at (1, 1)
# checking 0
# Tree value 0 at (1, 2)
# checking 0
# Tree value 0 at (1, 3)
# checking 1
# Tree value 1 at (1, 4)
# checking 1
# Tree value 2 at (1, 5)
# checking 0
# Tree value 2 at (1, 6)
# checking 2
# Tree value 2 at (1, 7)
# checking 1
# Tree value 0 at (1, 8)
# checking 1
# Tree value 3 at (1, 9)
# checking 3
# Tree value 2 at (1, 10)
# checking 1
# Tree value 2 at (1, 11)
# checking 0
# Tree value 3 at (1, 12)
# checking 1
# Tree value 1 at (1, 13)
# checking 2
# Tree value 2 at (1, 14)
# checking 0
# Tree value 2 at (1, 15)
# checking 3
# Tree value 0 at (1, 16)
# checking 0
# Tree value 3 at (1, 17)
# checking 1
# Tree value 3 at (1, 18)
# checking 1
# Tree value 2 at (1, 19)
# checking 2
# Tree value 0 at (1, 20)
# checking 1
# Tree value 4 at (1, 21)
# checking 3
# Tree value 2 at (1, 22)
# checking 1
# Tree value 3 at (1, 23)
# checking 2
# Tree value 3 at (1, 24)
# checking 2
# Tree value 3 at (1, 25)
# checking 0
# Tree value 0 at (1, 26)
# checking 0
# Tree value 1 at (1, 27)
# checking 3
# Tree value 0 at (1, 28)
# checking 0
# Tree value 0 at (1, 29)
# checking 1
# Tree value 1 at (1, 30)
# checking 0
# Tree value 4 at (1, 31)
# checking 1
# Tree value 1 at (1, 32)
# checking 3
# Tree value 1 at (1, 33)
# checking 2
# Tree value 2 at (1, 34)
# checking 0
# Tree value 3 at (1, 35)
# checking 4
# Tree value 4 at (1, 36)
# checking 2
# Tree value 3 at (1, 37)
# checking 1
# Tree value 2 at (1, 38)
# checking 3
# Tree value 2 at (1, 39)
# checking 4
# Tree value 3 at (1, 40)
# checking 3
# Tree value 2 at (1, 41)
# checking 3
# Tree value 5 at (1, 42)
# checking 3
# Tree value 5 at (1, 43)
# checking 2
# Tree value 5 at (1, 44)
# checking 1
# Tree value 5 at (1, 45)
# checking 3
# Tree value 5 at (1, 46)
# checking 2
# Tree value 2 at (1, 47)
# checking 4
# Tree value 1 at (1, 48)
# checking 4
# Tree value 3 at (1, 49)
# checking 5
# Tree value 1 at (1, 50)
# checking 4
# Tree value 5 at (1, 51)
# checking 1
# Tree value 1 at (1, 52)
# checking 2
# Tree value 3 at (1, 53)
# checking 5
# Tree value 4 at (1, 54)
# checking 5
# Tree value 1 at (1, 55)
# checking 3
# Tree value 3 at (1, 56)
# checking 4
# Tree value 3 at (1, 57)
# checking 1
# Tree value 3 at (1, 58)
# checking 2
# Tree value 3 at (1, 59)
# checking 0
# Tree value 2 at (1, 60)
# checking 4
# Tree value 4 at (1, 61)
# checking 1
# Tree value 3 at (1, 62)
# checking 1
# Tree value 2 at (1, 63)
# checking 3
# Tree value 0 at (1, 64)
# checking 1
# Tree value 1 at (1, 65)
# checking 4
# Tree value 0 at (1, 66)
# checking 2
# Tree value 4 at (1, 67)
# checking 2
# Tree value 1 at (1, 68)
# checking 1
# Tree value 4 at (1, 69)
# checking 4
# Tree value 1 at (1, 70)
# checking 2
# Tree value 4 at (1, 71)
# checking 1
# Tree value 1 at (1, 72)
# checking 4
# Tree value 2 at (1, 73)
# checking 3
# Tree value 0 at (1, 74)
# checking 2
# Tree value 4 at (1, 75)
# checking 2
# Tree value 1 at (1, 76)
# checking 0
# Tree value 4 at (1, 77)
# checking 4
# Tree value 4 at (1, 78)
# checking 2
# Tree value 0 at (1, 79)
# checking 1
# Tree value 4 at (1, 80)
# checking 3
# Tree value 2 at (1, 81)
# checking 1
# Tree value 2 at (1, 82)
# checking 2
# Tree value 2 at (1, 83)
# checking 3
# Tree value 3 at (1, 84)
# checking 3
# Tree value 0 at (1, 85)
# checking 1
# Tree value 0 at (1, 86)
# checking 2
# Tree value 2 at (1, 87)
# checking 0
# Tree value 1 at (1, 88)
# checking 1
# Tree value 2 at (1, 89)
# checking 0
# Tree value 0 at (1, 90)
# checking 1
# Tree value 3 at (1, 91)
# checking 2
# Tree value 1 at (1, 92)
# checking 0
# Tree value 2 at (1, 93)
# checking 2
# Tree value 1 at (1, 94)
# checking 2
# Tree value 2 at (1, 95)
# checking 0
# Tree value 2 at (1, 96)
# checking 2
# Tree value 1 at (1, 97)
# checking 1
# Tree value 1 at (2, 1)
# checking 2
# Tree value 2 at (2, 2)
# checking 0
# checking 0
# Tree value 2 at (2, 3)
# checking 0
# checking 1
# Tree value 2 at (2, 4)
# checking 1
# checking 1
# Tree value 0 at (2, 5)
# checking 2
# Tree value 2 at (2, 6)
# checking 2
# Tree value 2 at (2, 7)
# checking 2
# Tree value 3 at (2, 8)
# checking 0
# checking 1
# Tree value 0 at (2, 9)
# checking 3
# Tree value 3 at (2, 10)
# checking 2
# checking 1
# Tree value 0 at (2, 11)
# checking 2
# Tree value 0 at (2, 12)
# checking 3
# Tree value 3 at (2, 13)
# checking 1
# checking 2
# Tree value 3 at (2, 14)
# checking 2
# checking 0
# Tree value 0 at (2, 15)
# checking 2
# Tree value 3 at (2, 16)
# checking 0
# checking 0
# Tree value 0 at (2, 17)
# checking 3
# Tree value 2 at (2, 18)
# checking 3
# Tree value 4 at (2, 19)
# checking 2
# checking 2
# Tree value 4 at (2, 20)
# checking 0
# checking 1
# Tree value 4 at (2, 21)
# checking 4
# Tree value 3 at (2, 22)
# checking 2
# checking 1
# Tree value 0 at (2, 23)
# checking 3
# Tree value 2 at (2, 24)
# checking 3
# Tree value 1 at (2, 25)
# checking 3
# Tree value 1 at (2, 26)
# checking 0
# checking 0
# Tree value 2 at (2, 27)
# checking 1
# checking 3
# Tree value 3 at (2, 28)
# checking 0
# checking 0
# Tree value 4 at (2, 29)
# checking 0
# checking 1
# Tree value 2 at (2, 30)
# checking 1
# checking 0
# Tree value 2 at (2, 31)
# checking 4
# Tree value 0 at (2, 32)
# checking 1
# Tree value 0 at (2, 33)
# checking 1
# Tree value 4 at (2, 34)
# checking 2
# checking 0
# Tree value 5 at (2, 35)
# checking 3
# checking 4
# Tree value 5 at (2, 36)
# checking 4
# checking 2
# Tree value 5 at (2, 37)
# checking 3
# checking 1
# Tree value 5 at (2, 38)
# checking 2
# checking 3
# Tree value 3 at (2, 39)
# checking 2
# checking 4
# Tree value 5 at (2, 40)
# checking 3
# checking 3
# Tree value 2 at (2, 41)
# checking 2
# Tree value 5 at (2, 42)
# checking 5
# Tree value 1 at (2, 43)
# checking 5
# Tree value 4 at (2, 44)
# checking 5
# Tree value 2 at (2, 45)
# checking 5
# Tree value 5 at (2, 46)
# checking 5
# Tree value 4 at (2, 47)
# checking 2
# checking 4
# Tree value 3 at (2, 48)
# checking 1
# checking 4
# Tree value 3 at (2, 49)
# checking 3
# Tree value 5 at (2, 50)
# checking 1
# checking 4
# Tree value 3 at (2, 51)
# checking 5
# Tree value 4 at (2, 52)
# checking 1
# checking 2
# Tree value 3 at (2, 53)
# checking 3
# Tree value 3 at (2, 54)
# checking 4
# Tree value 3 at (2, 55)
# checking 1
# checking 3
# Tree value 2 at (2, 56)
# checking 3
# Tree value 5 at (2, 57)
# checking 3
# checking 1
# Tree value 1 at (2, 58)
# checking 3
# Tree value 4 at (2, 59)
# checking 3
# checking 0
# Tree value 2 at (2, 60)
# checking 2
# Tree value 4 at (2, 61)
# checking 4
# Tree value 3 at (2, 62)
# checking 3
# Tree value 3 at (2, 63)
# checking 2
# checking 3
# Tree value 4 at (2, 64)
# checking 0
# checking 1
# Tree value 5 at (2, 65)
# checking 1
# checking 4
# Tree value 2 at (2, 66)
# checking 0
# checking 2
# Tree value 0 at (2, 67)
# checking 4
# Tree value 2 at (2, 68)
# checking 1
# checking 1
# Tree value 2 at (2, 69)
# checking 4
# Tree value 0 at (2, 70)
# checking 1
# Tree value 1 at (2, 71)
# checking 4
# Tree value 0 at (2, 72)
# checking 1
# Tree value 1 at (2, 73)
# checking 2
# Tree value 3 at (2, 74)
# checking 0
# checking 2
# Tree value 1 at (2, 75)
# checking 4
# Tree value 2 at (2, 76)
# checking 1
# checking 0
# Tree value 0 at (2, 77)
# checking 4
# Tree value 3 at (2, 78)
# checking 4
# Tree value 0 at (2, 79)
# checking 0
# Tree value 3 at (2, 80)
# checking 4
# Tree value 1 at (2, 81)
# checking 2
# Tree value 2 at (2, 82)
# checking 2
# Tree value 3 at (2, 83)
# checking 2
# checking 3
# Tree value 0 at (2, 84)
# checking 3
# Tree value 0 at (2, 85)
# checking 0
# Tree value 3 at (2, 86)
# checking 0
# checking 2
# Tree value 0 at (2, 87)
# checking 2
# Tree value 3 at (2, 88)
# checking 1
# checking 1
# Tree value 1 at (2, 89)
# checking 2
# Tree value 3 at (2, 90)
# checking 0
# checking 1
# Tree value 2 at (2, 91)
# checking 3
# Tree value 2 at (2, 92)
# checking 1
# checking 0
# Tree value 3 at (2, 93)
# checking 2
# checking 2
# Tree value 0 at (2, 94)
# checking 1
# Tree value 1 at (2, 95)
# checking 2
# Tree value 1 at (2, 96)
# checking 2
# Tree value 2 at (2, 97)
# checking 1
# checking 1
# Tree value 2 at (3, 1)
# checking 1
# checking 2
# Tree value 2 at (3, 2)
# checking 2
# Tree value 2 at (3, 3)
# checking 2
# Tree value 1 at (3, 4)
# checking 2
# Tree value 2 at (3, 5)
# checking 0
# checking 2
# Tree value 1 at (3, 6)
# checking 2
# Tree value 2 at (3, 7)
# checking 2
# Tree value 3 at (3, 8)
# checking 3
# Tree value 2 at (3, 9)
# checking 0
# checking 3
# Tree value 0 at (3, 10)
# checking 3
# Tree value 3 at (3, 11)
# checking 0
# checking 2
# checking 0
# Tree value 0 at (3, 12)
# checking 0
# Tree value 0 at (3, 13)
# checking 3
# Tree value 2 at (3, 14)
# checking 3
# Tree value 0 at (3, 15)
# checking 0
# Tree value 0 at (3, 16)
# checking 3
# Tree value 4 at (3, 17)
# checking 0
# checking 3
# checking 1
# Tree value 0 at (3, 18)
# checking 2
# Tree value 3 at (3, 19)
# checking 4
# Tree value 4 at (3, 20)
# checking 4
# Tree value 0 at (3, 21)
# checking 4
# Tree value 0 at (3, 22)
# checking 3
# Tree value 1 at (3, 23)
# checking 0
# checking 3
# Tree value 2 at (3, 24)
# checking 2
# Tree value 0 at (3, 25)
# checking 1
# Tree value 3 at (3, 26)
# checking 1
# checking 0
# checking 0
# Tree value 3 at (3, 27)
# checking 2
# checking 1
# checking 3
# Tree value 1 at (3, 28)
# checking 3
# Tree value 3 at (3, 29)
# checking 4
# Tree value 2 at (3, 30)
# checking 2
# Tree value 3 at (3, 31)
# checking 2
# checking 4
# Tree value 2 at (3, 32)
# checking 0
# checking 1
# checking 3
# Tree value 5 at (3, 33)
# checking 0
# checking 1
# checking 2
# Tree value 1 at (3, 34)
# checking 4
# Tree value 5 at (3, 35)
# checking 5
# Tree value 1 at (3, 36)
# checking 5
# Tree value 1 at (3, 37)
# checking 5
# Tree value 2 at (3, 38)
# checking 5
# Tree value 5 at (3, 39)
# checking 3
# checking 2
# checking 4
# Tree value 4 at (3, 40)
# checking 5
# Tree value 3 at (3, 41)
# checking 2
# checking 2
# checking 3
# Tree value 5 at (3, 42)
# checking 5
# Tree value 2 at (3, 43)
# checking 1
# checking 5
# Tree value 5 at (3, 44)
# checking 4
# checking 5
# Tree value 2 at (3, 45)
# checking 2
# Tree value 5 at (3, 46)
# checking 5
# Tree value 1 at (3, 47)
# checking 4
# Tree value 4 at (3, 48)
# checking 3
# checking 1
# checking 4
# Tree value 4 at (3, 49)
# checking 3
# checking 3
# checking 5
# Tree value 5 at (3, 50)
# checking 5
# Tree value 3 at (3, 51)
# checking 3
# Tree value 5 at (3, 52)
# checking 4
# checking 1
# checking 2
# Tree value 3 at (3, 53)
# checking 3
# Tree value 4 at (3, 54)
# checking 3
# checking 4
# Tree value 3 at (3, 55)
# checking 3
# Tree value 4 at (3, 56)
# checking 2
# checking 3
# checking 4
# Tree value 2 at (3, 57)
# checking 5
# Tree value 2 at (3, 58)
# checking 1
# checking 3
# Tree value 4 at (3, 59)
# checking 4
# Tree value 4 at (3, 60)
# checking 2
# checking 2
# checking 4
# Tree value 1 at (3, 61)
# checking 4
# Tree value 4 at (3, 62)
# checking 3
# checking 3
# checking 1
# Tree value 5 at (3, 63)
# checking 3
# checking 2
# checking 3
# Tree value 3 at (3, 64)
# checking 4
# Tree value 3 at (3, 65)
# checking 5
# Tree value 5 at (3, 66)
# checking 2
# checking 0
# checking 2
# Tree value 2 at (3, 67)
# checking 0
# checking 4
# Tree value 4 at (3, 68)
# checking 2
# checking 1
# checking 1
# Tree value 0 at (3, 69)
# checking 2
# Tree value 1 at (3, 70)
# checking 0
# checking 1
# Tree value 4 at (3, 71)
# checking 1
# checking 4
# Tree value 0 at (3, 72)
# checking 0
# Tree value 2 at (3, 73)
# checking 1
# checking 2
# Tree value 0 at (3, 74)
# checking 3
# Tree value 2 at (3, 75)
# checking 1
# checking 4
# Tree value 4 at (3, 76)
# checking 2
# checking 1
# checking 0
# Tree value 2 at (3, 77)
# checking 0
# checking 4
# Tree value 2 at (3, 78)
# checking 3
# Tree value 4 at (3, 79)
# checking 0
# checking 0
# checking 1
# Tree value 2 at (3, 80)
# checking 3
# Tree value 3 at (3, 81)
# checking 1
# checking 2
# checking 1
# Tree value 2 at (3, 82)
# checking 2
# Tree value 2 at (3, 83)
# checking 3
# Tree value 3 at (3, 84)
# checking 0
# checking 3
# Tree value 2 at (3, 85)
# checking 0
# checking 0
# checking 1
# Tree value 0 at (3, 86)
# checking 3
# Tree value 2 at (3, 87)
# checking 0
# checking 2
# Tree value 2 at (3, 88)
# checking 3
# Tree value 3 at (3, 89)
# checking 1
# checking 2
# checking 0
# Tree value 0 at (3, 90)
# checking 3
# Tree value 1 at (3, 91)
# checking 2
# Tree value 0 at (3, 92)
# checking 2
# Tree value 1 at (3, 93)
# checking 3
# Tree value 3 at (3, 94)
# checking 0
# checking 1
# checking 2
# Tree value 1 at (3, 95)
# checking 1
# Tree value 1 at (3, 96)
# checking 1
# Tree value 1 at (3, 97)
# checking 2
# Tree value 2 at (4, 1)
# checking 2
# Tree value 1 at (4, 2)
# checking 2
# Tree value 1 at (4, 3)
# checking 2
# Tree value 0 at (4, 4)
# checking 1
# Tree value 2 at (4, 5)
# checking 2
# Tree value 3 at (4, 6)
# checking 1
# checking 2
# checking 2
# checking 2
# Tree value 3 at (4, 7)
# checking 2
# checking 2
# checking 2
# checking 1
# Tree value 3 at (4, 8)
# checking 3
# Tree value 1 at (4, 9)
# checking 2
# Tree value 0 at (4, 10)
# checking 0
# Tree value 3 at (4, 11)
# checking 3
# Tree value 3 at (4, 12)
# checking 0
# checking 0
# checking 3
# Tree value 3 at (4, 13)
# checking 0
# checking 3
# Tree value 3 at (4, 14)
# checking 2
# checking 3
# Tree value 2 at (4, 15)
# checking 0
# checking 0
# checking 2
# Tree value 2 at (4, 16)
# checking 0
# checking 3
# Tree value 1 at (4, 17)
# checking 4
# Tree value 4 at (4, 18)
# checking 0
# checking 2
# checking 3
# checking 1
# Tree value 1 at (4, 19)
# checking 3
# Tree value 1 at (4, 20)
# checking 4
# Tree value 3 at (4, 21)
# checking 0
# checking 4
# Tree value 2 at (4, 22)
# checking 0
# checking 3
# Tree value 4 at (4, 23)
# checking 1
# checking 0
# checking 3
# checking 2
# Tree value 2 at (4, 24)
# checking 2
# Tree value 0 at (4, 25)
# checking 0
# Tree value 3 at (4, 26)
# checking 3
# Tree value 0 at (4, 27)
# checking 3
# Tree value 3 at (4, 28)
# checking 1
# checking 3
# Tree value 4 at (4, 29)
# checking 3
# checking 4
# Tree value 2 at (4, 30)
# checking 2
# Tree value 3 at (4, 31)
# checking 3
# Tree value 5 at (4, 32)
# checking 2
# checking 0
# checking 1
# checking 3
# Tree value 1 at (4, 33)
# checking 5
# Tree value 3 at (4, 34)
# checking 1
# checking 4
# Tree value 5 at (4, 35)
# checking 5
# Tree value 3 at (4, 36)
# checking 1
# checking 5
# Tree value 4 at (4, 37)
# checking 1
# checking 5
# Tree value 3 at (4, 38)
# checking 2
# checking 5
# Tree value 4 at (4, 39)
# checking 5
# Tree value 5 at (4, 40)
# checking 4
# checking 5
# Tree value 5 at (4, 41)
# checking 3
# checking 2
# checking 2
# checking 3
# Tree value 4 at (4, 42)
# checking 5
# Tree value 1 at (4, 43)
# checking 2
# Tree value 5 at (4, 44)
# checking 5
# Tree value 4 at (4, 45)
# checking 2
# checking 2
# checking 5
# Tree value 2 at (4, 46)
# checking 5
# Tree value 5 at (4, 47)
# checking 1
# checking 4
# checking 2
# checking 4
# Tree value 1 at (4, 48)
# checking 4
# Tree value 3 at (4, 49)
# checking 4
# Tree value 4 at (4, 50)
# checking 5
# Tree value 2 at (4, 51)
# checking 3
# Tree value 5 at (4, 52)
# checking 5
# Tree value 1 at (4, 53)
# checking 3
# Tree value 2 at (4, 54)
# checking 4
# Tree value 2 at (4, 55)
# checking 3
# Tree value 1 at (4, 56)
# checking 4
# Tree value 5 at (4, 57)
# checking 2
# checking 5
# Tree value 2 at (4, 58)
# checking 2
# Tree value 1 at (4, 59)
# checking 4
# Tree value 3 at (4, 60)
# checking 4
# Tree value 5 at (4, 61)
# checking 1
# checking 4
# checking 4
# checking 1
# Tree value 2 at (4, 62)
# checking 4
# Tree value 5 at (4, 63)
# checking 5
# Tree value 1 at (4, 64)
# checking 3
# Tree value 2 at (4, 65)
# checking 3
# Tree value 4 at (4, 66)
# checking 5
# Tree value 4 at (4, 67)
# checking 2
# checking 0
# checking 4
# Tree value 5 at (4, 68)
# checking 4
# checking 2
# checking 1
# checking 1
# Tree value 3 at (4, 69)
# checking 0
# checking 2
# checking 4
# Tree value 4 at (4, 70)
# checking 1
# checking 0
# checking 1
# checking 2
# Tree value 3 at (4, 71)
# checking 4
# Tree value 4 at (4, 72)
# checking 0
# checking 0
# checking 1
# checking 4
# Tree value 4 at (4, 73)
# checking 2
# checking 1
# checking 2
# checking 3
# Tree value 4 at (4, 74)
# checking 0
# checking 3
# checking 0
# checking 2
# Tree value 2 at (4, 75)
# checking 2
# Tree value 4 at (4, 76)
# checking 4
# Tree value 2 at (4, 77)
# checking 2
# Tree value 4 at (4, 78)
# checking 2
# checking 3
# checking 4
# Tree value 1 at (4, 79)
# checking 4
# Tree value 0 at (4, 80)
# checking 2
# Tree value 3 at (4, 81)
# checking 3
# Tree value 4 at (4, 82)
# checking 2
# checking 2
# checking 2
# checking 2
# Tree value 3 at (4, 83)
# checking 2
# checking 3
# Tree value 1 at (4, 84)
# checking 3
# Tree value 3 at (4, 85)
# checking 2
# checking 0
# checking 0
# checking 1
# Tree value 3 at (4, 86)
# checking 0
# checking 3
# Tree value 0 at (4, 87)
# checking 2
# Tree value 3 at (4, 88)
# checking 2
# checking 3
# Tree value 1 at (4, 89)
# checking 3
# Tree value 0 at (4, 90)
# checking 0
# Tree value 2 at (4, 91)
# checking 1
# checking 2
# Tree value 2 at (4, 92)
# checking 0
# checking 2
# Tree value 2 at (4, 93)
# checking 1
# checking 3
# Tree value 1 at (4, 94)
# checking 3
# Tree value 3 at (4, 95)
# checking 1
# checking 1
# checking 2
# checking 0
# Tree value 1 at (4, 96)
# checking 1
# Tree value 1 at (4, 97)
# checking 1
# Tree value 1 at (5, 1)
# checking 2
# Tree value 2 at (5, 2)
# checking 1
# checking 2
# Tree value 2 at (5, 3)
# checking 1
# checking 2
# Tree value 3 at (5, 4)
# checking 0
# checking 1
# checking 2
# checking 1
# checking 1
# Tree value 0 at (5, 5)
# checking 2
# Tree value 1 at (5, 6)
# checking 3
# Tree value 1 at (5, 7)
# checking 3
# Tree value 0 at (5, 8)
# checking 3
# Tree value 2 at (5, 9)
# checking 1
# checking 2
# Tree value 2 at (5, 10)
# checking 0
# checking 0
# checking 3
# Tree value 0 at (5, 11)
# checking 3
# Tree value 2 at (5, 12)
# checking 3
# Tree value 3 at (5, 13)
# checking 3
# Tree value 2 at (5, 14)
# checking 3
# Tree value 1 at (5, 15)
# checking 2
# Tree value 3 at (5, 16)
# checking 2
# checking 0
# checking 3
# Tree value 0 at (5, 17)
# checking 1
# Tree value 0 at (5, 18)
# checking 4
# Tree value 4 at (5, 19)
# checking 1
# checking 3
# checking 4
# Tree value 3 at (5, 20)
# checking 1
# checking 4
# Tree value 3 at (5, 21)
# checking 3
# Tree value 2 at (5, 22)
# checking 2
# Tree value 1 at (5, 23)
# checking 4
# Tree value 1 at (5, 24)
# checking 2
# Tree value 3 at (5, 25)
# checking 0
# checking 0
# checking 1
# checking 3
# Tree value 0 at (5, 26)
# checking 3
# Tree value 1 at (5, 27)
# checking 0
# checking 3
# Tree value 4 at (5, 28)
# checking 3
# checking 1
# checking 3
# checking 0
# checking 0
# Tree value 2 at (5, 29)
# checking 4
# Tree value 4 at (5, 30)
# checking 2
# checking 2
# checking 2
# checking 1
# checking 0
# Tree value 2 at (5, 31)
# checking 3
# Tree value 4 at (5, 32)
# checking 5
# Tree value 5 at (5, 33)
# checking 1
# checking 5
# Tree value 4 at (5, 34)
# checking 3
# checking 1
# checking 4
# Tree value 3 at (5, 35)
# checking 5
# Tree value 4 at (5, 36)
# checking 3
# checking 1
# checking 5
# Tree value 1 at (5, 37)
# checking 4
# Tree value 5 at (5, 38)
# checking 3
# checking 2
# checking 5
# Tree value 5 at (5, 39)
# checking 4
# checking 5
# Tree value 4 at (5, 40)
# checking 5
# Tree value 2 at (5, 41)
# checking 5
# Tree value 3 at (5, 42)
# checking 4
# Tree value 5 at (5, 43)
# checking 1
# checking 2
# checking 1
# checking 5
# Tree value 2 at (5, 44)
# checking 5
# Tree value 5 at (5, 45)
# checking 4
# checking 2
# checking 2
# checking 5
# Tree value 3 at (5, 46)
# checking 2
# checking 5
# Tree value 4 at (5, 47)
# checking 5
# Tree value 1 at (5, 48)
# checking 1
# Tree value 5 at (5, 49)
# checking 3
# checking 4
# checking 3
# checking 3
# checking 5
# Tree value 5 at (5, 50)
# checking 4
# checking 5
# Tree value 1 at (5, 51)
# checking 2
# Tree value 4 at (5, 52)
# checking 5
# Tree value 5 at (5, 53)
# checking 1
# checking 3
# checking 3
# checking 3
# checking 5
# Tree value 4 at (5, 54)
# checking 2
# checking 4
# Tree value 3 at (5, 55)
# checking 2
# checking 3
# Tree value 4 at (5, 56)
# checking 1
# checking 4
# Tree value 3 at (5, 57)
# checking 5
# Tree value 2 at (5, 58)
# checking 2
# Tree value 4 at (5, 59)
# checking 1
# checking 4
# Tree value 4 at (5, 60)
# checking 3
# checking 4
# Tree value 3 at (5, 61)
# checking 5
# Tree value 2 at (5, 62)
# checking 2
# Tree value 5 at (5, 63)
# checking 5
# Tree value 5 at (5, 64)
# checking 1
# checking 3
# checking 4
# checking 0
# checking 1
# Tree value 3 at (5, 65)
# checking 2
# checking 3
# Tree value 5 at (5, 66)
# checking 4
# checking 5
# Tree value 3 at (5, 67)
# checking 4
# Tree value 2 at (5, 68)
# checking 5
# Tree value 2 at (5, 69)
# checking 3
# Tree value 5 at (5, 70)
# checking 4
# checking 1
# checking 0
# checking 1
# checking 2
# Tree value 3 at (5, 71)
# checking 3
# Tree value 5 at (5, 72)
# checking 4
# checking 0
# checking 0
# checking 1
# checking 4
# Tree value 1 at (5, 73)
# checking 4
# Tree value 0 at (5, 74)
# checking 4
# Tree value 1 at (5, 75)
# checking 2
# Tree value 0 at (5, 76)
# checking 4
# Tree value 1 at (5, 77)
# checking 2
# Tree value 0 at (5, 78)
# checking 4
# Tree value 4 at (5, 79)
# checking 1
# checking 4
# Tree value 3 at (5, 80)
# checking 0
# checking 2
# checking 3
# Tree value 4 at (5, 81)
# checking 3
# checking 3
# checking 1
# checking 2
# checking 1
# Tree value 2 at (5, 82)
# checking 4
# Tree value 2 at (5, 83)
# checking 3
# Tree value 1 at (5, 84)
# checking 1
# Tree value 1 at (5, 85)
# checking 3
# Tree value 0 at (5, 86)
# checking 3
# Tree value 3 at (5, 87)
# checking 0
# checking 2
# checking 0
# checking 2
# checking 0
# Tree value 1 at (5, 88)
# checking 3
# Tree value 1 at (5, 89)
# checking 1
# Tree value 3 at (5, 90)
# checking 0
# checking 0
# checking 3
# Tree value 0 at (5, 91)
# checking 2
# Tree value 2 at (5, 92)
# checking 2
# Tree value 1 at (5, 93)
# checking 2
# Tree value 3 at (5, 94)
# checking 1
# checking 3
# Tree value 3 at (5, 95)
# checking 3
# Tree value 3 at (5, 96)
# checking 1
# checking 1
# checking 1
# checking 2
# checking 2
# Tree value 2 at (5, 97)
# checking 1
# checking 1
# checking 2
# Tree value 2 at (6, 1)
# checking 1
# checking 2
# Tree value 1 at (6, 2)
# checking 2
# Tree value 2 at (6, 3)
# checking 2
# Tree value 1 at (6, 4)
# checking 3
# Tree value 1 at (6, 5)
# checking 0
# checking 2
# Tree value 3 at (6, 6)
# checking 1
# checking 3
# Tree value 3 at (6, 7)
# checking 1
# checking 3
# Tree value 2 at (6, 8)
# checking 0
# checking 3
# Tree value 1 at (6, 9)
# checking 2
# Tree value 1 at (6, 10)
# checking 2
# Tree value 0 at (6, 11)
# checking 0
# Tree value 3 at (6, 12)
# checking 2
# checking 3
# Tree value 3 at (6, 13)
# checking 3
# Tree value 1 at (6, 14)
# checking 2
# Tree value 2 at (6, 15)
# checking 1
# checking 2
# Tree value 2 at (6, 16)
# checking 3
# Tree value 2 at (6, 17)
# checking 0
# checking 1
# checking 4
# Tree value 4 at (6, 18)
# checking 0
# checking 4
# Tree value 3 at (6, 19)
# checking 4
# Tree value 2 at (6, 20)
# checking 3
# Tree value 0 at (6, 21)
# checking 3
# Tree value 1 at (6, 22)
# checking 2
# Tree value 2 at (6, 23)
# checking 1
# checking 4
# Tree value 2 at (6, 24)
# checking 1
# checking 2
# Tree value 2 at (6, 25)
# checking 3
# Tree value 5 at (6, 26)
# checking 0
# checking 3
# checking 3
# checking 1
# checking 0
# checking 0
# Tree value 1 at (6, 27)
# checking 1
# Tree value 3 at (6, 28)
# checking 4
# Tree value 4 at (6, 29)
# checking 2
# checking 4
# Tree value 4 at (6, 30)
# checking 4
# Tree value 2 at (6, 31)
# checking 2
# Tree value 2 at (6, 32)
# checking 4
# Tree value 4 at (6, 33)
# checking 5
# Tree value 3 at (6, 34)
# checking 4
# Tree value 2 at (6, 35)
# checking 3
# Tree value 3 at (6, 36)
# checking 4
# Tree value 4 at (6, 37)
# checking 1
# checking 4
# Tree value 1 at (6, 38)
# checking 5
# Tree value 1 at (6, 39)
# checking 5
# Tree value 1 at (6, 40)
# checking 4
# Tree value 2 at (6, 41)
# checking 2
# Tree value 1 at (6, 42)
# checking 3
# Tree value 4 at (6, 43)
# checking 5
# Tree value 4 at (6, 44)
# checking 2
# checking 5
# Tree value 4 at (6, 45)
# checking 5
# Tree value 2 at (6, 46)
# checking 3
# Tree value 1 at (6, 47)
# checking 4
# Tree value 5 at (6, 48)
# checking 1
# checking 1
# checking 4
# checking 3
# checking 1
# checking 4
# Tree value 3 at (6, 49)
# checking 5
# Tree value 5 at (6, 50)
# checking 5
# Tree value 1 at (6, 51)
# checking 1
# Tree value 5 at (6, 52)
# checking 4
# checking 5
# Tree value 3 at (6, 53)
# checking 5
# Tree value 3 at (6, 54)
# checking 4
# Tree value 5 at (6, 55)
# checking 3
# checking 2
# checking 3
# checking 3
# checking 1
# checking 3
# Tree value 1 at (6, 56)
# checking 4
# Tree value 5 at (6, 57)
# checking 3
# checking 5
# Tree value 4 at (6, 58)
# checking 2
# checking 2
# checking 2
# checking 1
# checking 3
# checking 2
# Tree value 5 at (6, 59)
# checking 4
# checking 1
# checking 4
# checking 4
# checking 3
# checking 0
# Tree value 1 at (6, 60)
# checking 4
# Tree value 2 at (6, 61)
# checking 3
# Tree value 2 at (6, 62)
# checking 2
# Tree value 1 at (6, 63)
# checking 5
# Tree value 3 at (6, 64)
# checking 5
# Tree value 4 at (6, 65)
# checking 3
# checking 2
# checking 3
# checking 5
# Tree value 2 at (6, 66)
# checking 5
# Tree value 4 at (6, 67)
# checking 3
# checking 4
# Tree value 2 at (6, 68)
# checking 2
# Tree value 2 at (6, 69)
# checking 2
# Tree value 3 at (6, 70)
# checking 5
# Tree value 2 at (6, 71)
# checking 3
# Tree value 1 at (6, 72)
# checking 5
# Tree value 5 at (6, 73)
# checking 1
# checking 4
# checking 2
# checking 1
# checking 2
# checking 3
# Tree value 2 at (6, 74)
# checking 0
# checking 4
# Tree value 1 at (6, 75)
# checking 1
# Tree value 3 at (6, 76)
# checking 0
# checking 4
# Tree value 0 at (6, 77)
# checking 1
# Tree value 1 at (6, 78)
# checking 0
# checking 4
# Tree value 1 at (6, 79)
# checking 4
# Tree value 0 at (6, 80)
# checking 3
# Tree value 3 at (6, 81)
# checking 4
# Tree value 3 at (6, 82)
# checking 2
# checking 4
# Tree value 4 at (6, 83)
# checking 2
# checking 3
# checking 2
# checking 3
# checking 2
# checking 3
# Tree value 1 at (6, 84)
# checking 1
# Tree value 1 at (6, 85)
# checking 1
# Tree value 4 at (6, 86)
# checking 0
# checking 3
# checking 0
# checking 3
# checking 0
# checking 2
# Tree value 4 at (6, 87)
# checking 3
# checking 0
# checking 2
# checking 0
# checking 2
# checking 0
# Tree value 0 at (6, 88)
# checking 1
# Tree value 0 at (6, 89)
# checking 1
# Tree value 3 at (6, 90)
# checking 3
# Tree value 3 at (6, 91)
# checking 0
# checking 2
# checking 1
# checking 2
# checking 3
# Tree value 2 at (6, 92)
# checking 2
# Tree value 2 at (6, 93)
# checking 1
# checking 2
# Tree value 1 at (6, 94)
# checking 3
# Tree value 2 at (6, 95)
# checking 3
# Tree value 3 at (6, 96)
# checking 3
# Tree value 0 at (6, 97)
# checking 2
# Tree value 2 at (7, 1)
# checking 2
# Tree value 1 at (7, 2)
# checking 1
# Tree value 0 at (7, 3)
# checking 2
# Tree value 0 at (7, 4)
# checking 1
# Tree value 3 at (7, 5)
# checking 1
# checking 0
# checking 2
# checking 2
# checking 0
# checking 2
# checking 0
# Tree value 0 at (7, 6)
# checking 3
# Tree value 2 at (7, 7)
# checking 3
# Tree value 0 at (7, 8)
# checking 2
# Tree value 2 at (7, 9)
# checking 1
# checking 2
# Tree value 2 at (7, 10)
# checking 1
# checking 2
# Tree value 2 at (7, 11)
# checking 0
# checking 0
# checking 3
# Tree value 2 at (7, 12)
# checking 3
# Tree value 2 at (7, 13)
# checking 3
# Tree value 2 at (7, 14)
# checking 1
# checking 2
# Tree value 3 at (7, 15)
# checking 2
# checking 1
# checking 2
# checking 0
# checking 0
# checking 2
# checking 3
# Tree value 0 at (7, 16)
# checking 2
# Tree value 4 at (7, 17)
# checking 2
# checking 0
# checking 1
# checking 4
# Tree value 1 at (7, 18)
# checking 4
# Tree value 1 at (7, 19)
# checking 3
# Tree value 4 at (7, 20)
# checking 2
# checking 3
# checking 1
# checking 4
# Tree value 0 at (7, 21)
# checking 0
# Tree value 2 at (7, 22)
# checking 1
# checking 2
# Tree value 2 at (7, 23)
# checking 2
# Tree value 5 at (7, 24)
# checking 2
# checking 1
# checking 2
# checking 2
# checking 2
# checking 3
# checking 2
# Tree value 5 at (7, 25)
# checking 2
# checking 3
# checking 0
# checking 0
# checking 1
# checking 3
# checking 0
# Tree value 2 at (7, 26)
# checking 5
# Tree value 3 at (7, 27)
# checking 1
# checking 1
# checking 0
# checking 3
# Tree value 1 at (7, 28)
# checking 3
# Tree value 5 at (7, 29)
# checking 4
# checking 2
# checking 4
# checking 3
# checking 4
# checking 0
# checking 1
# Tree value 5 at (7, 30)
# checking 4
# checking 4
# checking 2
# checking 2
# checking 2
# checking 1
# checking 0
# Tree value 5 at (7, 31)
# checking 2
# checking 2
# checking 3
# checking 3
# checking 2
# checking 4
# checking 1
# Tree value 2 at (7, 32)
# checking 2
# Tree value 4 at (7, 33)
# checking 4
# Tree value 1 at (7, 34)
# checking 3
# Tree value 1 at (7, 35)
# checking 2
# Tree value 2 at (7, 36)
# checking 3
# Tree value 5 at (7, 37)
# checking 4
# checking 1
# checking 4
# checking 1
# checking 5
# Tree value 5 at (7, 38)
# checking 1
# checking 5
# Tree value 5 at (7, 39)
# checking 1
# checking 5
# Tree value 5 at (7, 40)
# checking 1
# checking 4
# checking 5
# Tree value 4 at (7, 41)
# checking 2
# checking 2
# checking 5
# Tree value 2 at (7, 42)
# checking 1
# checking 3
# Tree value 2 at (7, 43)
# checking 4
# Tree value 1 at (7, 44)
# checking 4
# Tree value 1 at (7, 45)
# checking 4
# Tree value 6 at (7, 46)
# checking 2
# checking 3
# checking 2
# checking 5
# checking 5
# checking 5
# checking 2
# Tree value 2 at (7, 47)
# checking 1
# checking 4
# Tree value 4 at (7, 48)
# checking 5
# Tree value 5 at (7, 49)
# checking 3
# checking 5
# Tree value 5 at (7, 50)
# checking 5
# Tree value 2 at (7, 51)
# checking 1
# checking 1
# checking 2
# Tree value 6 at (7, 52)
# checking 5
# checking 4
# checking 5
# checking 5
# checking 4
# checking 1
# checking 2
# Tree value 3 at (7, 53)
# checking 3
# Tree value 6 at (7, 54)
# checking 3
# checking 4
# checking 2
# checking 4
# checking 3
# checking 4
# checking 5
# Tree value 4 at (7, 55)
# checking 5
# Tree value 3 at (7, 56)
# checking 1
# checking 4
# Tree value 3 at (7, 57)
# checking 5
# Tree value 5 at (7, 58)
# checking 4
# checking 2
# checking 2
# checking 2
# checking 1
# checking 3
# checking 2
# Tree value 1 at (7, 59)
# checking 5
# Tree value 1 at (7, 60)
# checking 1
# Tree value 1 at (7, 61)
# checking 2
# Tree value 2 at (7, 62)
# checking 2
# Tree value 3 at (7, 63)
# checking 1
# checking 5
# Tree value 3 at (7, 64)
# checking 3
# Tree value 3 at (7, 65)
# checking 4
# Tree value 3 at (7, 66)
# checking 2
# checking 5
# Tree value 2 at (7, 67)
# checking 4
# Tree value 2 at (7, 68)
# checking 2
# Tree value 2 at (7, 69)
# checking 2
# Tree value 3 at (7, 70)
# checking 3
# Tree value 5 at (7, 71)
# checking 2
# checking 3
# checking 3
# checking 4
# checking 1
# checking 4
# checking 1
# Tree value 2 at (7, 72)
# checking 1
# checking 5
# Tree value 1 at (7, 73)
# checking 5
# Tree value 4 at (7, 74)
# checking 2
# checking 0
# checking 4
# Tree value 3 at (7, 75)
# checking 1
# checking 1
# checking 2
# checking 2
# checking 1
# checking 4
# Tree value 5 at (7, 76)
# checking 3
# checking 0
# checking 4
# checking 4
# checking 2
# checking 1
# checking 0
# Tree value 3 at (7, 77)
# checking 0
# checking 1
# checking 2
# checking 2
# checking 0
# checking 4
# Tree value 4 at (7, 78)
# checking 1
# checking 0
# checking 4
# Tree value 2 at (7, 79)
# checking 1
# checking 4
# Tree value 4 at (7, 80)
# checking 0
# checking 3
# checking 0
# checking 2
# checking 3
# checking 4
# Tree value 1 at (7, 81)
# checking 3
# Tree value 4 at (7, 82)
# checking 3
# checking 2
# checking 4
# Tree value 0 at (7, 83)
# checking 4
# Tree value 1 at (7, 84)
# checking 1
# Tree value 0 at (7, 85)
# checking 1
# Tree value 1 at (7, 86)
# checking 4
# Tree value 1 at (7, 87)
# checking 4
# Tree value 1 at (7, 88)
# checking 0
# checking 1
# Tree value 0 at (7, 89)
# checking 0
# Tree value 3 at (7, 90)
# checking 3
# Tree value 0 at (7, 91)
# checking 3
# Tree value 1 at (7, 92)
# checking 2
# Tree value 0 at (7, 93)
# checking 2
# Tree value 1 at (7, 94)
# checking 1
# Tree value 3 at (7, 95)
# checking 2
# checking 3
# Tree value 3 at (7, 96)
# checking 3
# Tree value 0 at (7, 97)
# checking 0
# Tree value 1 at (8, 1)
# checking 2
# Tree value 1 at (8, 2)
# checking 1
# Tree value 1 at (8, 3)
# checking 0
# checking 2
# Tree value 0 at (8, 4)
# checking 0
# Tree value 1 at (8, 5)
# checking 3
# Tree value 3 at (8, 6)
# checking 0
# checking 3
# Tree value 3 at (8, 7)
# checking 2
# checking 3
# Tree value 1 at (8, 8)
# checking 0
# checking 2
# Tree value 3 at (8, 9)
# checking 2
# checking 1
# checking 2
# checking 1
# checking 2
# checking 0
# checking 3
# Tree value 3 at (8, 10)
# checking 2
# checking 1
# checking 2
# checking 0
# checking 0
# checking 3
# Tree value 2 at (8, 11)
# checking 2
# Tree value 3 at (8, 12)
# checking 2
# checking 3
# Tree value 0 at (8, 13)
# checking 2
# Tree value 3 at (8, 14)
# checking 2
# checking 1
# checking 2
# checking 3
# Tree value 1 at (8, 15)
# checking 3
# Tree value 3 at (8, 16)
# checking 0
# checking 2
# checking 3
# Tree value 4 at (8, 17)
# checking 4
# Tree value 3 at (8, 18)
# checking 1
# checking 4
# Tree value 2 at (8, 19)
# checking 1
# checking 3
# Tree value 0 at (8, 20)
# checking 4
# Tree value 0 at (8, 21)
# checking 0
# Tree value 2 at (8, 22)
# checking 2
# Tree value 5 at (8, 23)
# checking 2
# checking 2
# checking 1
# checking 4
# checking 1
# checking 0
# checking 3
# checking 2
# Tree value 2 at (8, 24)
# checking 5
# Tree value 3 at (8, 25)
# checking 5
# Tree value 5 at (8, 26)
# checking 2
# checking 5
# Tree value 2 at (8, 27)
# checking 3
# Tree value 5 at (8, 28)
# checking 1
# checking 3
# checking 4
# checking 3
# checking 1
# checking 3
# checking 0
# checking 0
# Tree value 4 at (8, 29)
# checking 5
# Tree value 5 at (8, 30)
# checking 5
# Tree value 2 at (8, 31)
# checking 5
# Tree value 3 at (8, 32)
# checking 2
# checking 2
# checking 4
# Tree value 3 at (8, 33)
# checking 4
# Tree value 4 at (8, 34)
# checking 1
# checking 3
# checking 4
# Tree value 1 at (8, 35)
# checking 1
# Tree value 1 at (8, 36)
# checking 2
# Tree value 3 at (8, 37)
# checking 5
# Tree value 4 at (8, 38)
# checking 5
# Tree value 2 at (8, 39)
# checking 5
# Tree value 2 at (8, 40)
# checking 5
# Tree value 5 at (8, 41)
# checking 4
# checking 2
# checking 2
# checking 5
# Tree value 2 at (8, 42)
# checking 2
# Tree value 4 at (8, 43)
# checking 2
# checking 4
# Tree value 6 at (8, 44)
# checking 1
# checking 4
# checking 2
# checking 5
# checking 5
# checking 4
# checking 5
# checking 1
# Tree value 3 at (8, 45)
# checking 1
# checking 4
# Tree value 3 at (8, 46)
# checking 6
# Tree value 5 at (8, 47)
# checking 2
# checking 1
# checking 4
# checking 5
# Tree value 5 at (8, 48)
# checking 4
# checking 5
# Tree value 5 at (8, 49)
# checking 5
# Tree value 4 at (8, 50)
# checking 5
# Tree value 3 at (8, 51)
# checking 2
# checking 1
# checking 1
# checking 2
# checking 3
# Tree value 5 at (8, 52)
# checking 6
# Tree value 6 at (8, 53)
# checking 3
# checking 3
# checking 5
# checking 1
# checking 3
# checking 3
# checking 3
# checking 5
# Tree value 5 at (8, 54)
# checking 6
# Tree value 3 at (8, 55)
# checking 4
# Tree value 3 at (8, 56)
# checking 3
# Tree value 4 at (8, 57)
# checking 3
# checking 5
# Tree value 2 at (8, 58)
# checking 5
# Tree value 6 at (8, 59)
# checking 1
# checking 5
# checking 4
# checking 1
# checking 4
# checking 4
# checking 3
# checking 0
# Tree value 4 at (8, 60)
# checking 1
# checking 1
# checking 4
# Tree value 1 at (8, 61)
# checking 1
# Tree value 5 at (8, 62)
# checking 2
# checking 2
# checking 2
# checking 2
# checking 4
# checking 3
# checking 3
# checking 1
# Tree value 5 at (8, 63)
# checking 3
# checking 1
# checking 5
# Tree value 1 at (8, 64)
# checking 3
# Tree value 4 at (8, 65)
# checking 3
# checking 4
# Tree value 3 at (8, 66)
# checking 3
# Tree value 4 at (8, 67)
# checking 2
# checking 4
# Tree value 4 at (8, 68)
# checking 2
# checking 2
# checking 2
# checking 5
# Tree value 5 at (8, 69)
# checking 2
# checking 2
# checking 2
# checking 3
# checking 0
# checking 2
# checking 4
# checking 4
# Tree value 2 at (8, 70)
# checking 3
# Tree value 1 at (8, 71)
# checking 5
# Tree value 4 at (8, 72)
# checking 2
# checking 1
# checking 5
# Tree value 3 at (8, 73)
# checking 1
# checking 5
# Tree value 3 at (8, 74)
# checking 4
# Tree value 2 at (8, 75)
# checking 3
# Tree value 3 at (8, 76)
# checking 5
# Tree value 5 at (8, 77)
# checking 3
# checking 0
# checking 1
# checking 2
# checking 2
# checking 0
# checking 4
# checking 4
# Tree value 2 at (8, 78)
# checking 4
# Tree value 2 at (8, 79)
# checking 2
# Tree value 3 at (8, 80)
# checking 4
# Tree value 1 at (8, 81)
# checking 1
# Tree value 0 at (8, 82)
# checking 4
# Tree value 0 at (8, 83)
# checking 0
# Tree value 0 at (8, 84)
# checking 1
# Tree value 2 at (8, 85)
# checking 0
# checking 1
# checking 1
# checking 3
# Tree value 4 at (8, 86)
# checking 1
# checking 4
# Tree value 1 at (8, 87)
# checking 1
# Tree value 0 at (8, 88)
# checking 1
# Tree value 0 at (8, 89)
# checking 0
# Tree value 3 at (8, 90)
# checking 3
# Tree value 2 at (8, 91)
# checking 0
# checking 3
# Tree value 2 at (8, 92)
# checking 1
# checking 2
# Tree value 0 at (8, 93)
# checking 0
# Tree value 1 at (8, 94)
# checking 1
# Tree value 2 at (8, 95)
# checking 3
# Tree value 2 at (8, 96)
# checking 3
# Tree value 1 at (8, 97)
# checking 0
# checking 0
# checking 2
# Tree value 3 at (9, 1)
# checking 1
# checking 2
# checking 2
# checking 1
# checking 2
# checking 2
# checking 1
# checking 2
# checking 0
# Tree value 3 at (9, 2)
# checking 1
# checking 1
# checking 1
# checking 2
# checking 1
# checking 2
# checking 2
# checking 0
# checking 0
# Tree value 1 at (9, 3)
# checking 1
# Tree value 2 at (9, 4)
# checking 0
# checking 0
# checking 1
# checking 3
# Tree value 1 at (9, 5)
# checking 1
# Tree value 0 at (9, 6)
# checking 3
# Tree value 3 at (9, 7)
# checking 3
# Tree value 3 at (9, 8)
# checking 1
# checking 0
# checking 2
# checking 0
# checking 3
# Tree value 0 at (9, 9)
# checking 3
# Tree value 0 at (9, 10)
# checking 3
# Tree value 1 at (9, 11)
# checking 2
# Tree value 1 at (9, 12)
# checking 3
# Tree value 3 at (9, 13)
# checking 0
# checking 2
# checking 3
# Tree value 3 at (9, 14)
# checking 3
# Tree value 2 at (9, 15)
# checking 1
# checking 3
# Tree value 0 at (9, 16)
# checking 3
# Tree value 2 at (9, 17)
# checking 4
# Tree value 2 at (9, 18)
# checking 3
# Tree value 1 at (9, 19)
# checking 2
# Tree value 1 at (9, 20)
# checking 0
# checking 4
# Tree value 3 at (9, 21)
# checking 0
# checking 0
# checking 0
# checking 3
# Tree value 3 at (9, 22)
# checking 2
# checking 2
# checking 1
# checking 2
# checking 2
# checking 0
# checking 3
# Tree value 1 at (9, 23)
# checking 5
# Tree value 1 at (9, 24)
# checking 2
# Tree value 4 at (9, 25)
# checking 3
# checking 5
# Tree value 4 at (9, 26)
# checking 5
# Tree value 5 at (9, 27)
# checking 2
# checking 3
# checking 1
# checking 1
# checking 0
# checking 3
# checking 2
# checking 1
# checking 3
# Tree value 4 at (9, 28)
# checking 5
# Tree value 5 at (9, 29)
# checking 4
# checking 5
# Tree value 3 at (9, 30)
# checking 5
# Tree value 3 at (9, 31)
# checking 2
# checking 5
# Tree value 4 at (9, 32)
# checking 3
# checking 2
# checking 2
# checking 4
# Tree value 5 at (9, 33)
# checking 3
# checking 4
# checking 4
# checking 5
# Tree value 4 at (9, 34)
# checking 4
# Tree value 5 at (9, 35)
# checking 1
# checking 1
# checking 2
# checking 3
# checking 5
# Tree value 4 at (9, 36)
# checking 1
# checking 2
# checking 3
# checking 4
# Tree value 4 at (9, 37)
# checking 3
# checking 5
# Tree value 2 at (9, 38)
# checking 4
# Tree value 4 at (9, 39)
# checking 2
# checking 5
# Tree value 2 at (9, 40)
# checking 2
# Tree value 6 at (9, 41)
# checking 5
# checking 4
# checking 2
# checking 2
# checking 5
# checking 3
# checking 2
# checking 2
# checking 3
# Tree value 4 at (9, 42)
# checking 2
# checking 2
# checking 1
# checking 3
# checking 4
# Tree value 6 at (9, 43)
# checking 4
# checking 2
# checking 4
# checking 5
# checking 1
# checking 2
# checking 1
# checking 5
# checking 2
# Tree value 2 at (9, 44)
# checking 6
# Tree value 3 at (9, 45)
# checking 3
# Tree value 3 at (9, 46)
# checking 3
# Tree value 5 at (9, 47)
# checking 5
# Tree value 6 at (9, 48)
# checking 5
# checking 4
# checking 5
# checking 1
# checking 1
# checking 4
# checking 3
# checking 1
# checking 4
# Tree value 6 at (9, 49)
# checking 5
# checking 5
# checking 3
# checking 5
# checking 3
# checking 4
# checking 3
# checking 3
# checking 5
# Tree value 2 at (9, 50)
# checking 4
# Tree value 2 at (9, 51)
# checking 3
# Tree value 5 at (9, 52)
# checking 5
# Tree value 5 at (9, 53)
# checking 6
# Tree value 3 at (9, 54)
# checking 5
# Tree value 4 at (9, 55)
# checking 3
# checking 4
# Tree value 2 at (9, 56)
# checking 3
# Tree value 3 at (9, 57)
# checking 4
# Tree value 4 at (9, 58)
# checking 2
# checking 5
# Tree value 2 at (9, 59)
# checking 6
# Tree value 6 at (9, 60)
# checking 4
# checking 1
# checking 1
# checking 4
# checking 3
# checking 4
# checking 2
# checking 2
# checking 4
# Tree value 2 at (9, 61)
# checking 1
# checking 1
# checking 2
# Tree value 6 at (9, 62)
# checking 5
# checking 2
# checking 2
# checking 2
# checking 2
# checking 4
# checking 3
# checking 3
# checking 1
# Tree value 5 at (9, 63)
# checking 5
# Tree value 2 at (9, 64)
# checking 1
# checking 3
# Tree value 4 at (9, 65)
# checking 4
# Tree value 3 at (9, 66)
# checking 3
# Tree value 1 at (9, 67)
# checking 4
# Tree value 3 at (9, 68)
# checking 4
# Tree value 4 at (9, 69)
# checking 5
# Tree value 3 at (9, 70)
# checking 2
# checking 3
# Tree value 2 at (9, 71)
# checking 1
# checking 5
# Tree value 4 at (9, 72)
# checking 4
# Tree value 3 at (9, 73)
# checking 3
# Tree value 2 at (9, 74)
# checking 3
# Tree value 2 at (9, 75)
# checking 2
# Tree value 5 at (9, 76)
# checking 3
# checking 5
# Tree value 5 at (9, 77)
# checking 5
# Tree value 1 at (9, 78)
# checking 2
# Tree value 1 at (9, 79)
# checking 2
# Tree value 3 at (9, 80)
# checking 3
# Tree value 2 at (9, 81)
# checking 1
# checking 1
# checking 3
# Tree value 0 at (9, 82)
# checking 0
# Tree value 3 at (9, 83)
# checking 0
# checking 0
# checking 4
# Tree value 3 at (9, 84)
# checking 0
# checking 1
# checking 1
# checking 1
# checking 1
# checking 3
# Tree value 2 at (9, 85)
# checking 2
# Tree value 2 at (9, 86)
# checking 4
# Tree value 3 at (9, 87)
# checking 1
# checking 1
# checking 4
# Tree value 2 at (9, 88)
# checking 0
# checking 1
# checking 0
# checking 1
# checking 3
# Tree value 2 at (9, 89)
# checking 0
# checking 0
# checking 0
# checking 1
# checking 1
# checking 3
# Tree value 0 at (9, 90)
# checking 3
# Tree value 0 at (9, 91)
# checking 2
# Tree value 2 at (9, 92)
# checking 2
# Tree value 3 at (9, 93)
# checking 0
# checking 0
# checking 2
# checking 1
# checking 2
# checking 1
# checking 3
# Tree value 1 at (9, 94)
# checking 1
# Tree value 2 at (9, 95)
# checking 2
# Tree value 2 at (9, 96)
# checking 2
# Tree value 0 at (9, 97)
# checking 1
# Tree value 1 at (10, 1)
# checking 3
# Tree value 0 at (10, 2)
# checking 3
# Tree value 3 at (10, 3)
# checking 1
# checking 1
# checking 0
# checking 2
# checking 2
# checking 1
# checking 2
# checking 2
# checking 0
# checking 1
# Tree value 2 at (10, 4)
# checking 2
# Tree value 2 at (10, 5)
# checking 1
# checking 1
# checking 3
# Tree value 3 at (10, 6)
# checking 0
# checking 3
# Tree value 2 at (10, 7)
# checking 3
# Tree value 2 at (10, 8)
# checking 3
# Tree value 1 at (10, 9)
# checking 0
# checking 3
# Tree value 4 at (10, 10)
# checking 0
# checking 3
# checking 2
# checking 1
# checking 2
# checking 0
# checking 0
# checking 3
# checking 2
# checking 1
# Tree value 1 at (10, 11)
# checking 1
# Tree value 3 at (10, 12)
# checking 1
# checking 3
# Tree value 3 at (10, 13)
# checking 3
# Tree value 3 at (10, 14)
# checking 3
# Tree value 0 at (10, 15)
# checking 2
# Tree value 4 at (10, 16)
# checking 0
# checking 3
# checking 0
# checking 2
# checking 3
# checking 2
# checking 0
# checking 3
# checking 0
# checking 0
# Tree value 4 at (10, 17)
# checking 2
# checking 4
# Tree value 3 at (10, 18)
# checking 2
# checking 3
# Tree value 0 at (10, 19)
# checking 1
# Tree value 4 at (10, 20)
# checking 1
# checking 0
# checking 4
# Tree value 1 at (10, 21)
# checking 3
# Tree value 1 at (10, 22)
# checking 3
# Tree value 5 at (10, 23)
# checking 1
# checking 5
# Tree value 5 at (10, 24)
# checking 1
# checking 2
# checking 5
# Tree value 5 at (10, 25)
# checking 4
# checking 3
# checking 5
# Tree value 2 at (10, 26)
# checking 4
# Tree value 1 at (10, 27)
# checking 5
# Tree value 1 at (10, 28)
# checking 4
# Tree value 5 at (10, 29)
# checking 5
# Tree value 4 at (10, 30)
# checking 3
# checking 5
# Tree value 1 at (10, 31)
# checking 3
# Tree value 3 at (10, 32)
# checking 4
# Tree value 2 at (10, 33)
# checking 5
# Tree value 5 at (10, 34)
# checking 4
# checking 4
# checking 1
# checking 3
# checking 4
# checking 3
# checking 1
# checking 4
# checking 2
# checking 0
# Tree value 3 at (10, 35)
# checking 5
# Tree value 5 at (10, 36)
# checking 4
# checking 1
# checking 2
# checking 3
# checking 4
# checking 3
# checking 1
# checking 5
# Tree value 6 at (10, 37)
# checking 4
# checking 3
# checking 5
# checking 4
# checking 1
# checking 4
# checking 1
# checking 5
# checking 3
# checking 1
# Tree value 3 at (10, 38)
# checking 2
# checking 4
# Tree value 3 at (10, 39)
# checking 4
# Tree value 5 at (10, 40)
# checking 2
# checking 2
# checking 5
# Tree value 3 at (10, 41)
# checking 6
# Tree value 6 at (10, 42)
# checking 4
# checking 2
# checking 2
# checking 1
# checking 3
# checking 4
# checking 5
# checking 5
# checking 5
# checking 3
# Tree value 2 at (10, 43)
# checking 6
# Tree value 5 at (10, 44)
# checking 2
# checking 6
# Tree value 6 at (10, 45)
# checking 3
# checking 3
# checking 1
# checking 4
# checking 5
# checking 4
# checking 2
# checking 2
# checking 5
# checking 3
# Tree value 6 at (10, 46)
# checking 3
# checking 3
# checking 6
# Tree value 6 at (10, 47)
# checking 5
# checking 5
# checking 2
# checking 1
# checking 4
# checking 5
# checking 1
# checking 4
# checking 2
# checking 4
# Tree value 2 at (10, 48)
# checking 6
# Tree value 4 at (10, 49)
# checking 6
# Tree value 4 at (10, 50)
# checking 2
# checking 4
# Tree value 4 at (10, 51)
# checking 2
# checking 3
# checking 2
# checking 1
# checking 1
# checking 2
# checking 3
# checking 3
# checking 5
# Tree value 6 at (10, 52)
# checking 5
# checking 5
# checking 6
# Tree value 4 at (10, 53)
# checking 5
# Tree value 2 at (10, 54)
# checking 3
# Tree value 2 at (10, 55)
# checking 4
# Tree value 6 at (10, 56)
# checking 2
# checking 3
# checking 3
# checking 1
# checking 4
# checking 1
# checking 4
# checking 2
# checking 3
# checking 4
# Tree value 4 at (10, 57)
# checking 3
# checking 4
# Tree value 5 at (10, 58)
# checking 4
# checking 2
# checking 5
# Tree value 2 at (10, 59)
# checking 2
# Tree value 6 at (10, 60)
# checking 6
# Tree value 5 at (10, 61)
# checking 2
# checking 1
# checking 1
# checking 2
# checking 3
# checking 5
# Tree value 6 at (10, 62)
# checking 6
# Tree value 2 at (10, 63)
# checking 5
# Tree value 4 at (10, 64)
# checking 2
# checking 1
# checking 3
# checking 3
# checking 5
# Tree value 3 at (10, 65)
# checking 4
# Tree value 4 at (10, 66)
# checking 3
# checking 3
# checking 3
# checking 2
# checking 5
# Tree value 2 at (10, 67)
# checking 1
# checking 4
# Tree value 4 at (10, 68)
# checking 3
# checking 4
# Tree value 5 at (10, 69)
# checking 4
# checking 5
# Tree value 4 at (10, 70)
# checking 3
# checking 2
# checking 3
# checking 3
# checking 5
# Tree value 5 at (10, 71)
# checking 2
# checking 1
# checking 5
# Tree value 5 at (10, 72)
# checking 4
# checking 4
# checking 2
# checking 1
# checking 5
# Tree value 2 at (10, 73)
# checking 3
# Tree value 5 at (10, 74)
# checking 2
# checking 3
# checking 4
# checking 2
# checking 0
# checking 4
# checking 0
# checking 3
# checking 0
# checking 2
# Tree value 5 at (10, 75)
# checking 2
# checking 2
# checking 3
# checking 1
# checking 1
# checking 2
# checking 2
# checking 1
# checking 4
# checking 2
# Tree value 5 at (10, 76)
# checking 5
# Tree value 5 at (10, 77)
# checking 5
# Tree value 5 at (10, 78)
# checking 1
# checking 2
# checking 4
# checking 1
# checking 0
# checking 4
# checking 2
# checking 3
# checking 4
# checking 2
# Tree value 5 at (10, 79)
# checking 1
# checking 2
# checking 2
# checking 1
# checking 4
# checking 1
# checking 4
# checking 0
# checking 0
# checking 1
# Tree value 3 at (10, 80)
# checking 3
# Tree value 3 at (10, 81)
# checking 2
# checking 1
# checking 1
# checking 3
# Tree value 3 at (10, 82)
# checking 0
# checking 0
# checking 4
# Tree value 3 at (10, 83)
# checking 3
# Tree value 3 at (10, 84)
# checking 3
# Tree value 3 at (10, 85)
# checking 2
# checking 2
# checking 0
# checking 1
# checking 1
# checking 3
# Tree value 3 at (10, 86)
# checking 2
# checking 4
# Tree value 4 at (10, 87)
# checking 3
# checking 1
# checking 1
# checking 4
# Tree value 4 at (10, 88)
# checking 2
# checking 0
# checking 1
# checking 0
# checking 1
# checking 3
# checking 2
# checking 3
# checking 1
# checking 1
# Tree value 1 at (10, 89)
# checking 2
# Tree value 1 at (10, 90)
# checking 0
# checking 3
# Tree value 2 at (10, 91)
# checking 0
# checking 2
# Tree value 1 at (10, 92)
# checking 2
# Tree value 3 at (10, 93)
# checking 3
# Tree value 1 at (10, 94)
# checking 1
# Tree value 1 at (10, 95)
# checking 2
# Tree value 2 at (10, 96)
# checking 2
# Tree value 3 at (10, 97)
# checking 0
# checking 1
# checking 0
# checking 0
# checking 2
# checking 1
# checking 1
# checking 2
# checking 1
# checking 1
# Tree value 3 at (11, 1)
# checking 1
# checking 3
# Tree value 2 at (11, 2)
# checking 0
# checking 3
# Tree value 3 at (11, 3)
# checking 3
# Tree value 3 at (11, 4)
# checking 2
# checking 2
# checking 0
# checking 0
# checking 1
# checking 3
# Tree value 0 at (11, 5)
# checking 2
# Tree value 3 at (11, 6)
# checking 3
# Tree value 0 at (11, 7)
# checking 2
# Tree value 4 at (11, 8)
# checking 2
# checking 3
# checking 1
# checking 0
# checking 2
# checking 0
# checking 3
# checking 3
# checking 3
# checking 0
# checking 1
# Tree value 0 at (11, 9)
# checking 1
# Tree value 4 at (11, 10)
# checking 4
# Tree value 1 at (11, 11)
# checking 1
# Tree value 4 at (11, 12)
# checking 3
# checking 1
# checking 3
# checking 2
# checking 3
# checking 2
# checking 3
# checking 0
# checking 0
# checking 3
# checking 1
# Tree value 2 at (11, 13)
# checking 3
# Tree value 2 at (11, 14)
# checking 3
# Tree value 4 at (11, 15)
# checking 0
# checking 2
# checking 1
# checking 3
# checking 2
# checking 1
# checking 2
# checking 0
# checking 0
# checking 2
# checking 3
# Tree value 2 at (11, 16)
# checking 4
# Tree value 0 at (11, 17)
# checking 4
# Tree value 4 at (11, 18)
# checking 3
# checking 2
# checking 3
# checking 1
# checking 4
# Tree value 3 at (11, 19)
# checking 0
# checking 1
# checking 2
# checking 1
# checking 3
# Tree value 2 at (11, 20)
# checking 4
# Tree value 1 at (11, 21)
# checking 1
# Tree value 2 at (11, 22)
# checking 1
# checking 3
# Tree value 4 at (11, 23)
# checking 5
# Tree value 3 at (11, 24)
# checking 5
# Tree value 2 at (11, 25)
# checking 5
# Tree value 4 at (11, 26)
# checking 2
# checking 4
# Tree value 2 at (11, 27)
# checking 1
# checking 5
# Tree value 4 at (11, 28)
# checking 1
# checking 4
# Tree value 4 at (11, 29)
# checking 5
# Tree value 2 at (11, 30)
# checking 4
# Tree value 3 at (11, 31)
# checking 1
# checking 3
# Tree value 6 at (11, 32)
# checking 3
# checking 4
# checking 3
# checking 2
# checking 2
# checking 4
# checking 5
# checking 2
# checking 0
# checking 1
# checking 3
# Tree value 2 at (11, 33)
# checking 2
# Tree value 6 at (11, 34)
# checking 5
# checking 4
# checking 4
# checking 1
# checking 3
# checking 4
# checking 3
# checking 1
# checking 4
# checking 2
# checking 0
# Tree value 4 at (11, 35)
# checking 3
# checking 5
# Tree value 2 at (11, 36)
# checking 5
# Tree value 5 at (11, 37)
# checking 6
# Tree value 5 at (11, 38)
# checking 3
# checking 2
# checking 4
# checking 5
# Tree value 2 at (11, 39)
# checking 3
# Tree value 4 at (11, 40)
# checking 5
# Tree value 2 at (11, 41)
# checking 3
# Tree value 5 at (11, 42)
# checking 6
# Tree value 3 at (11, 43)
# checking 2
# checking 6
# Tree value 6 at (11, 44)
# checking 5
# checking 2
# checking 6
# Tree value 4 at (11, 45)
# checking 6
# Tree value 4 at (11, 46)
# checking 6
# Tree value 5 at (11, 47)
# checking 6
# Tree value 6 at (11, 48)
# checking 2
# checking 6
# Tree value 2 at (11, 49)
# checking 4
# Tree value 6 at (11, 50)
# checking 4
# checking 2
# checking 4
# checking 5
# checking 5
# checking 5
# checking 4
# checking 5
# checking 5
# checking 1
# checking 4
# Tree value 6 at (11, 51)
# checking 4
# checking 2
# checking 3
# checking 2
# checking 1
# checking 1
# checking 2
# checking 3
# checking 3
# checking 5
# checking 1
# Tree value 4 at (11, 52)
# checking 6
# Tree value 2 at (11, 53)
# checking 4
# Tree value 4 at (11, 54)
# checking 2
# checking 3
# checking 5
# Tree value 6 at (11, 55)
# checking 2
# checking 4
# checking 3
# checking 4
# checking 5
# checking 3
# checking 2
# checking 3
# checking 3
# checking 1
# checking 3
# ...
# checking 4
# Tree value 3 at (94, 50)
# checking 6
# Tree value 4 at (94, 51)
# checking 6
# Tree value 4 at (94, 52)
# checking 5
# Tree value 2 at (94, 53)
# checking 2
# Tree value 3 at (94, 54)
# checking 2
# checking 2
# checking 6
# Tree value 1 at (94, 55)
# checking 4
# Tree value 5 at (94, 56)
# checking 1
# checking 6
# Tree value 3 at (94, 57)
# checking 1
# checking 2
# checking 2
# checking 6
# Tree value 4 at (94, 58)
# checking 3
# checking 3
# checking 5
# Tree value 2 at (94, 59)
# checking 3
# Tree value 5 at (94, 60)
# checking 1
# checking 3
# checking 5
# Tree value 5 at (94, 61)
# checking 5
# Tree value 5 at (94, 62)
# checking 5
# Tree value 2 at (94, 63)
# checking 4
# Tree value 1 at (94, 64)
# checking 3
# Tree value 4 at (94, 65)
# checking 4
# Tree value 4 at (94, 66)
# checking 2
# checking 3
# checking 1
# checking 3
# checking 6
# Tree value 2 at (94, 67)
# checking 1
# checking 1
# checking 2
# Tree value 1 at (94, 68)
# checking 5
# Tree value 5 at (94, 69)
# checking 1
# checking 4
# checking 4
# checking 2
# checking 3
# checking 6
# Tree value 2 at (94, 70)
# checking 1
# checking 2
# Tree value 4 at (94, 71)
# checking 2
# checking 2
# checking 3
# checking 3
# checking 3
# checking 4
# Tree value 4 at (94, 72)
# checking 2
# checking 4
# Tree value 5 at (94, 73)
# checking 2
# checking 3
# checking 1
# checking 4
# checking 1
# checking 5
# Tree value 4 at (94, 74)
# checking 5
# Tree value 2 at (94, 75)
# checking 5
# Tree value 2 at (94, 76)
# checking 2
# Tree value 4 at (94, 77)
# checking 3
# checking 3
# checking 2
# checking 2
# checking 1
# checking 2
# checking 5
# Tree value 4 at (94, 78)
# checking 0
# checking 3
# checking 1
# checking 3
# checking 3
# checking 2
# checking 1
# checking 5
# Tree value 0 at (94, 79)
# checking 1
# Tree value 2 at (94, 80)
# checking 3
# Tree value 3 at (94, 81)
# checking 0
# checking 0
# checking 2
# checking 4
# Tree value 4 at (94, 82)
# checking 4
# Tree value 3 at (94, 83)
# checking 0
# checking 1
# checking 3
# Tree value 2 at (94, 84)
# checking 4
# Tree value 1 at (94, 85)
# checking 4
# Tree value 4 at (94, 86)
# checking 3
# checking 3
# checking 4
# Tree value 1 at (94, 87)
# checking 2
# Tree value 3 at (94, 88)
# checking 3
# Tree value 2 at (94, 89)
# checking 3
# Tree value 1 at (94, 90)
# checking 1
# Tree value 0 at (94, 91)
# checking 0
# Tree value 0 at (94, 92)
# checking 2
# Tree value 1 at (94, 93)
# checking 0
# checking 1
# Tree value 2 at (94, 94)
# checking 2
# Tree value 3 at (94, 95)
# checking 1
# checking 1
# checking 1
# checking 3
# Tree value 0 at (94, 96)
# checking 3
# Tree value 3 at (94, 97)
# checking 1
# checking 1
# checking 2
# checking 3
# Tree value 1 at (95, 1)
# checking 0
# checking 2
# Tree value 2 at (95, 2)
# checking 0
# checking 1
# checking 3
# Tree value 0 at (95, 3)
# checking 0
# Tree value 1 at (95, 4)
# checking 1
# Tree value 2 at (95, 5)
# checking 2
# Tree value 2 at (95, 6)
# checking 1
# checking 1
# checking 1
# checking 0
# checking 0
# checking 1
# checking 3
# Tree value 3 at (95, 7)
# checking 2
# checking 0
# checking 1
# checking 2
# checking 2
# checking 2
# checking 1
# checking 3
# Tree value 0 at (95, 8)
# checking 2
# Tree value 2 at (95, 9)
# checking 1
# checking 1
# checking 1
# checking 1
# checking 2
# Tree value 2 at (95, 10)
# checking 3
# Tree value 3 at (95, 11)
# checking 0
# checking 2
# checking 2
# checking 3
# Tree value 0 at (95, 12)
# checking 2
# Tree value 0 at (95, 13)
# checking 2
# Tree value 2 at (95, 14)
# checking 1
# checking 3
# Tree value 0 at (95, 15)
# checking 2
# Tree value 4 at (95, 16)
# checking 0
# checking 0
# checking 4
# Tree value 4 at (95, 17)
# checking 2
# checking 2
# checking 4
# Tree value 2 at (95, 18)
# checking 1
# checking 0
# checking 1
# checking 0
# checking 3
# Tree value 0 at (95, 19)
# checking 3
# Tree value 3 at (95, 20)
# checking 0
# checking 0
# checking 4
# Tree value 1 at (95, 21)
# checking 3
# Tree value 1 at (95, 22)
# checking 2
# Tree value 1 at (95, 23)
# checking 4
# Tree value 2 at (95, 24)
# checking 4
# Tree value 2 at (95, 25)
# checking 4
# Tree value 2 at (95, 26)
# checking 3
# Tree value 2 at (95, 27)
# checking 5
# Tree value 2 at (95, 28)
# checking 3
# Tree value 5 at (95, 29)
# checking 4
# checking 4
# checking 5
# Tree value 3 at (95, 30)
# checking 2
# checking 3
# Tree value 2 at (95, 31)
# checking 1
# checking 3
# Tree value 1 at (95, 32)
# checking 5
# Tree value 5 at (95, 33)
# checking 4
# checking 2
# checking 1
# checking 3
# checking 4
# checking 5
# Tree value 3 at (95, 34)
# checking 5
# Tree value 2 at (95, 35)
# checking 1
# checking 1
# checking 1
# checking 5
# Tree value 5 at (95, 36)
# checking 3
# checking 3
# checking 1
# checking 1
# checking 5
# Tree value 1 at (95, 37)
# checking 4
# Tree value 4 at (95, 38)
# checking 3
# checking 5
# Tree value 5 at (95, 39)
# checking 5
# Tree value 4 at (95, 40)
# checking 1
# checking 5
# Tree value 1 at (95, 41)
# checking 1
# Tree value 1 at (95, 42)
# checking 1
# Tree value 5 at (95, 43)
# checking 4
# checking 4
# checking 3
# checking 2
# checking 2
# checking 4
# checking 3
# checking 3
# checking 4
# checking 7
# Tree value 3 at (95, 44)
# checking 4
# Tree value 2 at (95, 45)
# checking 2
# Tree value 2 at (95, 46)
# checking 2
# Tree value 2 at (95, 47)
# checking 4
# Tree value 2 at (95, 48)
# checking 1
# checking 4
# Tree value 1 at (95, 49)
# checking 1
# Tree value 4 at (95, 50)
# checking 3
# checking 6
# Tree value 1 at (95, 51)
# checking 4
# Tree value 1 at (95, 52)
# checking 4
# Tree value 5 at (95, 53)
# checking 2
# checking 2
# checking 4
# checking 2
# checking 2
# checking 4
# checking 3
# checking 5
# Tree value 4 at (95, 54)
# checking 3
# checking 2
# checking 2
# checking 6
# Tree value 4 at (95, 55)
# checking 1
# checking 4
# Tree value 3 at (95, 56)
# checking 5
# Tree value 2 at (95, 57)
# checking 3
# Tree value 1 at (95, 58)
# checking 4
# Tree value 2 at (95, 59)
# checking 2
# Tree value 3 at (95, 60)
# checking 5
# Tree value 4 at (95, 61)
# checking 5
# Tree value 4 at (95, 62)
# checking 5
# Tree value 3 at (95, 63)
# checking 2
# checking 4
# Tree value 5 at (95, 64)
# checking 1
# checking 3
# checking 1
# checking 3
# checking 5
# Tree value 4 at (95, 65)
# checking 4
# Tree value 5 at (95, 66)
# checking 4
# checking 2
# checking 3
# checking 1
# checking 3
# checking 6
# Tree value 4 at (95, 67)
# checking 2
# checking 1
# checking 1
# checking 2
# checking 3
# checking 2
# checking 5
# Tree value 5 at (95, 68)
# checking 1
# checking 5
# Tree value 2 at (95, 69)
# checking 5
# Tree value 3 at (95, 70)
# checking 2
# checking 1
# checking 2
# checking 5
# Tree value 1 at (95, 71)
# checking 4
# Tree value 5 at (95, 72)
# checking 4
# checking 2
# checking 4
# checking 2
# checking 1
# checking 1
# checking 5
# Tree value 3 at (95, 73)
# checking 5
# Tree value 3 at (95, 74)
# checking 4
# Tree value 4 at (95, 75)
# checking 2
# checking 5
# Tree value 4 at (95, 76)
# checking 2
# checking 2
# checking 2
# checking 1
# checking 4
# Tree value 2 at (95, 77)
# checking 4
# Tree value 3 at (95, 78)
# checking 4
# Tree value 4 at (95, 79)
# checking 0
# checking 1
# checking 3
# checking 2
# checking 5
# Tree value 4 at (95, 80)
# checking 2
# checking 3
# checking 2
# checking 2
# checking 4
# Tree value 0 at (95, 81)
# checking 3
# Tree value 0 at (95, 82)
# checking 4
# Tree value 2 at (95, 83)
# checking 3
# Tree value 0 at (95, 84)
# checking 2
# Tree value 1 at (95, 85)
# checking 1
# Tree value 1 at (95, 86)
# checking 4
# Tree value 2 at (95, 87)
# checking 1
# checking 2
# Tree value 1 at (95, 88)
# checking 3
# Tree value 0 at (95, 89)
# checking 2
# Tree value 2 at (95, 90)
# checking 1
# checking 1
# checking 1
# checking 1
# checking 4
# Tree value 0 at (95, 91)
# checking 0
# Tree value 2 at (95, 92)
# checking 0
# checking 2
# Tree value 2 at (95, 93)
# checking 1
# checking 0
# checking 1
# checking 0
# checking 2
# Tree value 3 at (95, 94)
# checking 2
# checking 2
# checking 3
# Tree value 0 at (95, 95)
# checking 3
# Tree value 1 at (95, 96)
# checking 0
# checking 3
# Tree value 2 at (95, 97)
# checking 3
# Tree value 2 at (96, 1)
# checking 1
# checking 0
# checking 2
# Tree value 1 at (96, 2)
# checking 2
# Tree value 2 at (96, 3)
# checking 0
# checking 0
# checking 2
# Tree value 0 at (96, 4)
# checking 1
# Tree value 0 at (96, 5)
# checking 2
# Tree value 2 at (96, 6)
# checking 2
# Tree value 3 at (96, 7)
# checking 3
# Tree value 2 at (96, 8)
# checking 0
# checking 2
# Tree value 0 at (96, 9)
# checking 2
# Tree value 1 at (96, 10)
# checking 2
# Tree value 3 at (96, 11)
# checking 3
# Tree value 2 at (96, 12)
# checking 0
# checking 2
# Tree value 2 at (96, 13)
# checking 0
# checking 2
# Tree value 2 at (96, 14)
# checking 2
# Tree value 2 at (96, 15)
# checking 0
# checking 2
# Tree value 3 at (96, 16)
# checking 4
# Tree value 1 at (96, 17)
# checking 4
# Tree value 0 at (96, 18)
# checking 2
# Tree value 3 at (96, 19)
# checking 0
# checking 3
# Tree value 2 at (96, 20)
# checking 3
# Tree value 3 at (96, 21)
# checking 1
# checking 3
# Tree value 4 at (96, 22)
# checking 1
# checking 2
# checking 1
# checking 1
# checking 2
# checking 4
# Tree value 0 at (96, 23)
# checking 1
# Tree value 2 at (96, 24)
# checking 2
# Tree value 3 at (96, 25)
# checking 2
# checking 4
# Tree value 3 at (96, 26)
# checking 2
# checking 3
# Tree value 1 at (96, 27)
# checking 2
# Tree value 4 at (96, 28)
# checking 2
# checking 3
# checking 2
# checking 3
# checking 2
# checking 2
# checking 5
# Tree value 1 at (96, 29)
# checking 5
# Tree value 4 at (96, 30)
# checking 3
# checking 2
# checking 3
# checking 2
# checking 3
# checking 1
# checking 2
# checking 5
# Tree value 3 at (96, 31)
# checking 2
# checking 1
# checking 3
# Tree value 3 at (96, 32)
# checking 1
# checking 5
# Tree value 3 at (96, 33)
# checking 5
# Tree value 5 at (96, 34)
# checking 3
# checking 5
# Tree value 4 at (96, 35)
# checking 2
# checking 1
# checking 1
# checking 1
# checking 5
# Tree value 5 at (96, 36)
# checking 5
# Tree value 1 at (96, 37)
# checking 1
# Tree value 4 at (96, 38)
# checking 4
# Tree value 3 at (96, 39)
# checking 5
# Tree value 1 at (96, 40)
# checking 4
# Tree value 1 at (96, 41)
# checking 1
# Tree value 2 at (96, 42)
# checking 1
# checking 1
# checking 2
# Tree value 1 at (96, 43)
# checking 5
# Tree value 3 at (96, 44)
# checking 3
# Tree value 1 at (96, 45)
# checking 2
# Tree value 1 at (96, 46)
# checking 2
# Tree value 3 at (96, 47)
# checking 2
# checking 4
# Tree value 2 at (96, 48)
# checking 2
# Tree value 2 at (96, 49)
# checking 1
# checking 1
# checking 4
# Tree value 4 at (96, 50)
# checking 4
# Tree value 4 at (96, 51)
# checking 1
# checking 4
# Tree value 4 at (96, 52)
# checking 1
# checking 4
# Tree value 1 at (96, 53)
# checking 5
# Tree value 1 at (96, 54)
# checking 4
# Tree value 1 at (96, 55)
# checking 4
# Tree value 1 at (96, 56)
# checking 3
# Tree value 3 at (96, 57)
# checking 2
# checking 3
# Tree value 3 at (96, 58)
# checking 1
# checking 4
# Tree value 2 at (96, 59)
# checking 2
# Tree value 4 at (96, 60)
# checking 3
# checking 5
# Tree value 2 at (96, 61)
# checking 4
# Tree value 2 at (96, 62)
# checking 4
# Tree value 2 at (96, 63)
# checking 3
# Tree value 5 at (96, 64)
# checking 5
# Tree value 4 at (96, 65)
# checking 4
# Tree value 1 at (96, 66)
# checking 5
# Tree value 4 at (96, 67)
# checking 4
# Tree value 3 at (96, 68)
# checking 5
# Tree value 1 at (96, 69)
# checking 2
# Tree value 3 at (96, 70)
# checking 3
# Tree value 3 at (96, 71)
# checking 1
# checking 4
# Tree value 4 at (96, 72)
# checking 5
# Tree value 4 at (96, 73)
# checking 3
# checking 5
# Tree value 0 at (96, 74)
# checking 3
# Tree value 2 at (96, 75)
# checking 4
# Tree value 0 at (96, 76)
# checking 4
# Tree value 4 at (96, 77)
# checking 2
# checking 4
# Tree value 2 at (96, 78)
# checking 3
# Tree value 2 at (96, 79)
# checking 4
# Tree value 0 at (96, 80)
# checking 4
# Tree value 1 at (96, 81)
# checking 0
# checking 3
# Tree value 0 at (96, 82)
# checking 0
# Tree value 1 at (96, 83)
# checking 2
# Tree value 4 at (96, 84)
# checking 0
# checking 2
# checking 4
# Tree value 3 at (96, 85)
# checking 1
# checking 1
# checking 4
# Tree value 1 at (96, 86)
# checking 1
# Tree value 2 at (96, 87)
# checking 2
# Tree value 3 at (96, 88)
# checking 1
# checking 3
# Tree value 0 at (96, 89)
# checking 0
# Tree value 2 at (96, 90)
# checking 2
# Tree value 0 at (96, 91)
# checking 0
# Tree value 0 at (96, 92)
# checking 2
# Tree value 0 at (96, 93)
# checking 2
# Tree value 0 at (96, 94)
# checking 3
# Tree value 2 at (96, 95)
# checking 0
# checking 3
# Tree value 1 at (96, 96)
# checking 1
# Tree value 2 at (96, 97)
# checking 2
# Tree value 1 at (97, 1)
# checking 2
# Tree value 1 at (97, 2)
# checking 1
# Tree value 2 at (97, 3)
# checking 2
# Tree value 1 at (97, 4)
# checking 0
# checking 1
# Tree value 2 at (97, 5)
# checking 0
# checking 2
# Tree value 2 at (97, 6)
# checking 2
# Tree value 1 at (97, 7)
# checking 3
# Tree value 3 at (97, 8)
# checking 2
# checking 0
# checking 2
# checking 3
# Tree value 1 at (97, 9)
# checking 0
# checking 2
# Tree value 2 at (97, 10)
# checking 1
# checking 2
# Tree value 1 at (97, 11)
# checking 3
# Tree value 3 at (97, 12)
# checking 2
# checking 0
# checking 2
# checking 0
# checking 0
# checking 3
# Tree value 0 at (97, 13)
# checking 2
# Tree value 3 at (97, 14)
# checking 2
# checking 2
# checking 1
# checking 3
# Tree value 2 at (97, 15)
# checking 2
# Tree value 1 at (97, 16)
# checking 3
# Tree value 1 at (97, 17)
# checking 1
# Tree value 0 at (97, 18)
# checking 0
# Tree value 2 at (97, 19)
# checking 3
# Tree value 0 at (97, 20)
# checking 2
# Tree value 4 at (97, 21)
# checking 3
# checking 1
# checking 3
# checking 4
# Tree value 4 at (97, 22)
# checking 4
# Tree value 1 at (97, 23)
# checking 0
# checking 1
# Tree value 2 at (97, 24)
# checking 2
# Tree value 3 at (97, 25)
# checking 3
# Tree value 2 at (97, 26)
# checking 3
# Tree value 0 at (97, 27)
# checking 1
# Tree value 4 at (97, 28)
# checking 4
# Tree value 2 at (97, 29)
# checking 1
# checking 5
# Tree value 1 at (97, 30)
# checking 4
# Tree value 4 at (97, 31)
# checking 3
# checking 2
# checking 1
# checking 3
# checking 5
# Tree value 2 at (97, 32)
# checking 3
# Tree value 4 at (97, 33)
# checking 3
# checking 5
# Tree value 5 at (97, 34)
# checking 5
# Tree value 1 at (97, 35)
# checking 4
# Tree value 2 at (97, 36)
# checking 5
# Tree value 5 at (97, 37)
# checking 1
# checking 1
# checking 4
# checking 1
# checking 4
# checking 6
# Tree value 4 at (97, 38)
# checking 4
# Tree value 4 at (97, 39)
# checking 3
# checking 5
# Tree value 4 at (97, 40)
# checking 1
# checking 4
# Tree value 4 at (97, 41)
# checking 1
# checking 1
# checking 1
# checking 3
# checking 4
# Tree value 2 at (97, 42)
# checking 2
# Tree value 4 at (97, 43)
# checking 1
# checking 5
# Tree value 4 at (97, 44)
# checking 3
# checking 3
# checking 4
# Tree value 5 at (97, 45)
# checking 1
# checking 2
# checking 2
# checking 2
# checking 4
# checking 5
# Tree value 2 at (97, 46)
# checking 1
# checking 2
# Tree value 1 at (97, 47)
# checking 3
# Tree value 1 at (97, 48)
# checking 2
# Tree value 2 at (97, 49)
# checking 2
# Tree value 1 at (97, 50)
# checking 4
# Tree value 1 at (97, 51)
# checking 4
# Tree value 5 at (97, 52)
# checking 4
# checking 1
# checking 4
# checking 5
# Tree value 2 at (97, 53)
# checking 1
# checking 5
# Tree value 1 at (97, 54)
# checking 1
# Tree value 2 at (97, 55)
# checking 1
# checking 4
# Tree value 1 at (97, 56)
# checking 1
# Tree value 2 at (97, 57)
# checking 3
# Tree value 2 at (97, 58)
# checking 3
# Tree value 4 at (97, 59)
# checking 2
# checking 2
# checking 2
# checking 3
# checking 5
# Tree value 4 at (97, 60)
# checking 4
# Tree value 3 at (97, 61)
# checking 2
# checking 4
# Tree value 5 at (97, 62)
# checking 2
# checking 4
# checking 5
# Tree value 1 at (97, 63)
# checking 2
# Tree value 1 at (97, 64)
# checking 5
# Tree value 2 at (97, 65)
# checking 4
# Tree value 5 at (97, 66)
# checking 1
# checking 5
# Tree value 1 at (97, 67)
# checking 4
# Tree value 5 at (97, 68)
# checking 3
# checking 5
# Tree value 2 at (97, 69)
# checking 1
# checking 2
# Tree value 3 at (97, 70)
# checking 3
# Tree value 4 at (97, 71)
# checking 3
# checking 1
# checking 4
# Tree value 2 at (97, 72)
# checking 4
# Tree value 0 at (97, 73)
# checking 4
# Tree value 4 at (97, 74)
# checking 0
# checking 3
# checking 4
# Tree value 2 at (97, 75)
# checking 2
# Tree value 0 at (97, 76)
# checking 0
# Tree value 2 at (97, 77)
# checking 4
# Tree value 3 at (97, 78)
# checking 2
# checking 3
# Tree value 2 at (97, 79)
# checking 2
# Tree value 1 at (97, 80)
# checking 0
# checking 4
# Tree value 1 at (97, 81)
# checking 1
# Tree value 2 at (97, 82)
# checking 0
# checking 0
# checking 4
# Tree value 4 at (97, 83)
# checking 1
# checking 2
# checking 3
# checking 0
# checking 1
# checking 3
# checking 0
# checking 3
# checking 2
# checking 3
# checking 4
# Tree value 2 at (97, 84)
# checking 4
# Tree value 2 at (97, 85)
# checking 3
# Tree value 2 at (97, 86)
# checking 1
# checking 1
# checking 4
# Tree value 3 at (97, 87)
# checking 2
# checking 2
# checking 1
# checking 2
# checking 2
# checking 2
# checking 4
# Tree value 3 at (97, 88)
# checking 3
# Tree value 2 at (97, 89)
# checking 0
# checking 0
# checking 2
# Tree value 3 at (97, 90)
# checking 2
# checking 2
# checking 1
# checking 1
# checking 1
# checking 1
# checking 4
# Tree value 1 at (97, 91)
# checking 0
# checking 0
# checking 0
# checking 0
# checking 2
# Tree value 2 at (97, 92)
# checking 0
# checking 2
# Tree value 2 at (97, 93)
# checking 0
# checking 2
# Tree value 1 at (97, 94)
# checking 0
# checking 3
# Tree value 0 at (97, 95)
# checking 2
# Tree value 0 at (97, 96)
# checking 1
# Tree value 2 at (97, 97)
# checking 2
# 172224
